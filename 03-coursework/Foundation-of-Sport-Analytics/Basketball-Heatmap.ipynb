# %% [markdown]
# # Visualizing sports data: basketball
#
# In this notebook we're going to look at ways of visualizing performance in basketball. We are going to use the data that we were introduced to last week.
#
# Our analysis here is going to focus on the where the ball was thrown from, which is recorded using (x, y) co-ordinates, in the same way that we had the coordinates for the baseball data. This data is  easy to graph and illuminating.
#
# We choose three different ways to look at the data
#
# 1. shot outcome: scored, missed or blocked
# 2. shot types by player
# 3. narrowing the focus to a particular region of the court

# %%
# As usual, we begin by importing the packages we will need

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# The data consists of the shot log for the NBA season 2016/17

shot = pd.read_csv("../../Data/Week 3/NBA Shotlog_16_17.csv")
pd.set_option('display.max_columns', 100)
print(shot.columns.tolist())
shot.describe()
# Out:
# ['self_previous_shot', 'player_position', 'home_game', 'location_x', 'opponent_previous_shot', 'home_team', 'shot_type', 'points', 'away_team', 'location_y', 'time', 'date', 'shoot_player', 'time_from_last_shot', 'quarter', 'current_shot_outcome']
#           location_x         points    location_y  time_from_last_shot  \
# count  209675.000000  210072.000000  209675.00000        200072.000000
# mean      468.524507       2.316130     249.44723            33.279489
# std       345.063654       0.464965     111.02320            19.797357
# min         0.000000       2.000000       0.00000             0.000000
# 25%        94.000000       2.000000     197.00000            22.000000
# 50%       342.000000       2.000000     250.00000            31.000000
# 75%       843.000000       3.000000     303.00000            41.000000
# max       933.000000       3.000000     500.00000           255.000000
#
#              quarter
# count  210072.000000
# mean        2.480383
# std         1.136841
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         8.000000

# %% [markdown]
# From the print() command we have a good deal of information on each shot, including the name of the player, the type of shot, team names, time in the game and so on. From the .describe() we can see that there are over 210,000 shots in the data although there is a small number of shots with missing coordinates (around 400). Also note that the x-axis location variable (this is the sideline) ranges from 0 to 993, while the y-axis variable (this is the baseline) runs from 0 to 500.
#
# We can generate a simple plot as follows:

# %%
# A simple plot of coordinates

x = shot['location_x']
y = shot['location_y']
plt.scatter(x,y, s=.005,c='r', marker= '.')

# %% [markdown]
# One point to note about the data is that it does not include free throws - otherwise there would be a deep red concentration at the center of the free throw line.
#
# The plot above gives us a very clear picture of the location of shots, notably from under the basket and from the three point line. However, the plot does not take account of the proportions of the court. Moreover, it would be useful to add a grid to identify more clearly the different locations.
#
# The dimensions of the court defined by the NBA are 94 feet by 50 feet. We can specify that ratio using figsize = (a,b). Note that we can also scale this to control the size of the plot in our window (we divide both the x and y figsize by 6).

# %%
# A simple plot of coordinates, scaled for court dimensions and with grid added.

plt.figure(figsize=(94/6,50/6))
plt.scatter(x,y, s=.1,c='r', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='.5', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='red')

# %% [markdown]
# Rather than look at both ends of the court, we can just look at one half of the court by fixing the range of the x axis using plt.xlim, which we set to cover the right hand half court. Note that to maintain the same dimensions we also need to halve the x axis on figsize (to 94/12 rather than 94/6).

# %%
# The right hand half court

plt.figure(figsize=(94/12,50/6))
plt.scatter(x,y, s=.1,c='r', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linewidth='.5', color='black')
plt.grid(which='minor', linewidth='.5', color='red')
plt.xlim(933/2, 933)
# Out:
# (466.5, 933)

# %% [markdown]
# The last plot just shows us one half of the court. To include both halves but show only the half court, we can convert the coordinates from the left hand half court so that they have the same relative location on the right hand half court (of course, there should be no real difference in performance based on which end of the court the player is attacking, and the two halves are mirror images of each other).
#
# We can convert the plot to show shots from both ends on a half court if we adjust the coordinates. The x-axis runs from 0 to 933, so if we want to just show the right hand half court with all shots, we can recode the location_x variables, where x is less the 933/2 (the left had half court) as equal to "933 - location_x". This produces a mirror image of the x coordinate in the right hand half of the court. However, since the direction toward the basket is the reverse of the other half court, we need to take the mirror image of the y coordinate for shots in the left had half court - that is "500 - location_y".
#
# The following code (which works like an "if" statement in Excel) creates these mirror images:

# %%
shot['halfcourt_x'] =np.where(shot['location_x'] < 933/2, 933 - shot['location_x'],shot['location_x'])
shot['halfcourt_y'] =np.where(shot['location_x'] < 933/2, 500 - shot['location_y'],shot['location_y'])
shot.describe()
# Out:
#           location_x         points    location_y  time_from_last_shot  \
# count  209675.000000  210072.000000  209675.00000        200072.000000
# mean      468.524507       2.316130     249.44723            33.279489
# std       345.063654       0.464965     111.02320            19.797357
# min         0.000000       2.000000       0.00000             0.000000
# 25%        94.000000       2.000000     197.00000            22.000000
# 50%       342.000000       2.000000     250.00000            31.000000
# 75%       843.000000       3.000000     303.00000            41.000000
# max       933.000000       3.000000     500.00000           255.000000
#
#              quarter    halfcourt_x    halfcourt_y
# count  210072.000000  209675.000000  209675.000000
# mean        2.480383     799.731480     250.303947
# std         1.136841      89.606222     111.024160
# min         1.000000     468.000000       0.000000
# 25%         1.000000     720.000000     197.000000
# 50%         2.000000     841.000000     250.000000
# 75%         3.000000     878.000000     303.000000
# max         8.000000     933.000000     500.000000

# %% [markdown]
# Note that the sideline coordinates now only run between 468 and 933, but that the baseline coordinates still run between 0 and 500, even though all the y locations have been changed. We can now plot the half court data, noting that we now halve the x axis in figsize, to preserve the same proportions as before.

# %%
# all shots shown on a half court

hx = shot['halfcourt_x']
hy = shot['halfcourt_y']
plt.figure(figsize=(94/12,50/6))
plt.scatter(hx,hy, s=.01,c='r', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='.5', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='red')
plt.title("Shots", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Shots')

# %% [markdown]
# ## Easy self test
#
# Experiment with different sized markers. What size do you think gives you the best visual representation of the data? Why?

# %%
# s = .1

plt.figure(figsize=(94/12,50/6))
plt.scatter(hx,hy, s=.1,c='r', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='.5', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='red')
plt.title("Shots", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Shots')

# %%
# s = 1

plt.figure(figsize=(94/12,50/6))
plt.scatter(hx,hy, s=1,c='r', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='.5', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='red')
plt.title("Shots", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Shots')

# %%
# s = 10

plt.figure(figsize=(94/12,50/6))
plt.scatter(hx,hy, s=10,c='r', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='.5', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='red')
plt.title("Shots", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Shots')

# %%
# The best representation is where s = 0.1 because it gives the best representation of each shot taken without the markers
# encroaching on each other

# %% [markdown]
# ## More difficult self test
#
# Show all the shots on a halfcourt, but show the data with the baseline on the left, not on the right.

# %%
# The left hand half court

plt.figure(figsize=(94/12,50/6))
plt.scatter(x,y, s=.1,c='r', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linewidth='.5', color='black')
plt.grid(which='minor', linewidth='.5', color='red')
plt.xlim(0, 933/2)
# Out:
# (0, 466.5)

# %%
# take the mirror image of the x and y coordinates for shots in the right hand half court and transfer it to the LHS

shot['left_halfcourt_x'] =np.where(shot['location_x'] < 933/2, shot['location_x'],933 - shot['location_x'])
shot['left_halfcourt_y'] =np.where(shot['location_x'] < 933/2, shot['location_y'],500 - shot['location_y'])
shot.describe()
# Out:
#           location_x         points    location_y  time_from_last_shot  \
# count  209675.000000  210072.000000  209675.00000        200072.000000
# mean      468.524507       2.316130     249.44723            33.279489
# std       345.063654       0.464965     111.02320            19.797357
# min         0.000000       2.000000       0.00000             0.000000
# 25%        94.000000       2.000000     197.00000            22.000000
# 50%       342.000000       2.000000     250.00000            31.000000
# 75%       843.000000       3.000000     303.00000            41.000000
# max       933.000000       3.000000     500.00000           255.000000
#
#              quarter    halfcourt_x    halfcourt_y  left_halfcourt_x  \
# count  210072.000000  209675.000000  209675.000000     209675.000000
# mean        2.480383     799.731480     250.303947        133.268520
# std         1.136841      89.606222     111.024160         89.606222
# min         1.000000     468.000000       0.000000          0.000000
# 25%         1.000000     720.000000     197.000000         55.000000
# 50%         2.000000     841.000000     250.000000         92.000000
# 75%         3.000000     878.000000     303.000000        213.000000
# max         8.000000     933.000000     500.000000        465.000000
#
#        left_halfcourt_y
# count     209675.000000
# mean         249.696053
# std          111.024160
# min            0.000000
# 25%          197.000000
# 50%          250.000000
# 75%          303.000000
# max          500.000000

# %%
# all shots shown on LHS half court

lhx = shot['left_halfcourt_x']
lhy = shot['left_halfcourt_y']
plt.figure(figsize=(94/12,50/6))
plt.scatter(lhx,lhy, s=.01,c='r', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='.5', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='red')
plt.title("Shots", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Shots')

# %% [markdown]
# We now breakdown shots into three categories: scored, missed and blocked. To do this we simply create subsets of the shot df based on shot outcome.

# %%
# Scoring shots

Scored = shot[shot.current_shot_outcome == 'SCORED']
hxs = Scored['halfcourt_x']
hys = Scored['halfcourt_y']
plt.figure(figsize=(94/12,50/6))
plt.scatter(hxs,hys, s=.01,c='g', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='.5', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='red')
plt.title("Scored", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Scored')

# %%
# Missed Shots

Missed = shot[shot.current_shot_outcome == 'MISSED']

hxm = Missed['halfcourt_x']
hym = Missed['halfcourt_y']

plt.figure(figsize=(94/12,50/6))
plt.scatter(hxm,hym, s=.01,c='b', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='.5', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='red')
plt.title("Missed", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Missed')

# %%
# Blocked shots

Blocked = shot[shot.current_shot_outcome == 'BLOCKED']

hxb = Blocked['halfcourt_x']
hyb = Blocked['halfcourt_y']

plt.figure(figsize=(94/12,50/6))
plt.scatter(hxb,hyb, s=1,c='m', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='.5', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='red')
plt.title("Blocked", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Blocked')

# %% [markdown]
# While informative, the location of shots by shot type is not that surprising. There has been a lot of interest in recent years in the rise of the 3-point shot with evidence suggesting that in the past there were more more shots from distance inside the three-point line, and that these have tended to die out since the payoff is much lower than a shot from just outside the three-point. We don't have past data here to make the comparison.
#
# Probably the greatest interest lies in comparing individual players. We can do this easily by taking subsets as we did above. First it's useful to generate a list of player names.

# %%
# Comparing players

# We use a pivot table here to list players by shots

playersn = shot.groupby('shoot_player')['current_shot_outcome'].describe().reset_index()
playersn.sort_values(by = 'count', ascending = False)
# Out:
#               shoot_player count unique     top  freq
# 402      Russell Westbrook  1940      3  MISSED  1026
# 25          Andrew Wiggins  1568      3  MISSED   760
# 106          DeMar DeRozan  1545      3  MISSED   731
# 193           James Harden  1532      3  MISSED   772
# 28           Anthony Davis  1525      3  SCORED   770
# 88          Damian Lillard  1489      3  MISSED   728
# 257     Karl-Anthony Towns  1479      3  SCORED   802
# 175          Isaiah Thomas  1473      3  SCORED   682
# 262           Kemba Walker  1451      3  MISSED   695
# 424          Stephen Curry  1444      3  MISSED   713
# 62             CJ McCollum  1441      3  SCORED   692
# 230              John Wall  1434      3  MISSED   701
# 107       DeMarcus Cousins  1433      3  MISSED   681
# 119           Devin Booker  1430      3  MISSED   732
# 282           Kyrie Irving  1420      3  MISSED   673
# 68         Carmelo Anthony  1390      3  MISSED   750
# 271          Klay Thompson  1376      3  MISSED   689
# 370            Paul George  1348      3  MISSED   673
# 291           LeBron James  1344      3  SCORED   736
# 48            Bradley Beal  1321      3  SCORED   637
# 258          Kawhi Leonard  1312      3  MISSED   643
# 166        Harrison Barnes  1280      3  MISSED   631
# 158  Giannis Antetokounmpo  1257      3  SCORED   656
# 216           Jimmy Butler  1252      3  MISSED   624
# 112        Dennis Schroder  1215      3  MISSED   555
# 58             Brook Lopez  1173      3  MISSED   568
# 305             Marc Gasol  1160      3  MISSED   605
# 161         Gordon Hayward  1154      3  MISSED   567
# 160           Goran Dragic  1125      3  SCORED   534
# 237        Jordan Clarkson  1069      3  MISSED   534
# ..                     ...   ...    ...     ...   ...
# 240            Jordan Hill    13      3  MISSED     7
# 303           Manny Harris    13      3  MISSED     7
# 123          Diamond Stone    13      3  MISSED     7
# 252          Justin Harper    12      3  MISSED     6
# 139       Elliott Williams    12      3  SCORED     6
# 239          Jordan Farmar    12      3  MISSED     7
# 244           Josh Huestis    11      2  SCORED     6
# 328        Michael Gbinije    10      2  MISSED     9
# 37            Axel Toupane     9      2  SCORED     5
# 164        Greivis Vasquez     8      3  MISSED     5
# 73          Chinanu Onuaku     7      2  SCORED     5
# 309    Marcus Georges-Hunt     7      2  MISSED     5
# 57           Brice Johnson     7      3  MISSED     4
# 364        Patricio Garino     7      1  MISSED     7
# 138         Elijah Millsap     7      2  MISSED     6
# 151              Gary Neal     7      1  MISSED     7
# 174          Isaiah Taylor     7      3  MISSED     5
# 426            Steve Novak     7      2  MISSED     5
# 472         Walter Tavares     5      2  SCORED     4
# 228           John Jenkins     5      2  MISSED     3
# 289          Larry Sanders     4      2  MISSED     3
# 229         John Lucas III     4      2  MISSED     3
# 335             Mike Tobey     4      3  MISSED     2
# 32           Arinze Onuaku     4      2  MISSED     2
# 3           Aaron Harrison     4      1  MISSED     4
# 111      Demetrius Jackson     4      2  SCORED     3
# 203           Jarrett Jack     3      2  SCORED     2
# 38              Ben Bentil     3      1  MISSED     3
# 202         Jarnell Stokes     1      1  SCORED     1
# 377              RJ Hunter     1      1  MISSED     1
#
# [485 rows x 5 columns]

# %% [markdown]
# We now compare LeBron James with Steph Curry.

# %%
# LeBron subset

LeBron = shot[shot['shoot_player']=='LeBron James']
LeBron
# Out:
#       self_previous_shot player_position home_game  location_x  \
# 35023             MISSED              SF       Yes       131.0
# 35028             MISSED              SF       Yes       236.0
# 35030            BLOCKED              SF       Yes       264.0
# 35037             SCORED              SF       Yes        50.0
# 35044             MISSED              SF       Yes        52.0
# 35054             MISSED              SF       Yes        52.0
# 35055             SCORED              SF       Yes        67.0
# 35061             MISSED              SF       Yes        52.0
# 35062             SCORED              SF       Yes        52.0
# 35073             MISSED              SF       Yes        50.0
# 35074             MISSED              SF       Yes       151.0
# 35081             SCORED              SF       Yes       888.0
# 35082             SCORED              SF       Yes       888.0
# 35101             SCORED              SF       Yes       814.0
# 35121             MISSED              SF        No       833.0
# 35122             MISSED              SF        No       878.0
# 35127             SCORED              SF        No       882.0
# 35133             SCORED              SF        No       878.0
# 35134             MISSED              SF        No       895.0
# 35143             MISSED              SF        No       878.0
# 35144             SCORED              SF        No       886.0
# 35147             SCORED              SF        No       886.0
# 35149             MISSED              SF        No       878.0
# 35167             SCORED              SF        No       303.0
# 35169             SCORED              SF        No       310.0
# 35173             SCORED              SF        No       166.0
# 35175             MISSED              SF        No       274.0
# 35183             SCORED              SF        No        40.0
# 35185             MISSED              SF        No        52.0
# 35194             SCORED              SF        No       177.0
# ...                  ...             ...       ...         ...
# 41683             MISSED              SF       Yes       900.0
# 41684             SCORED              SF       Yes       894.0
# 41690             SCORED              SF       Yes       888.0
# 41693             MISSED              SF       Yes       878.0
# 41697             MISSED              SF       Yes       890.0
# 41705             SCORED              SF       Yes       890.0
# 41706             MISSED              SF       Yes       890.0
# 41717             MISSED              SF       Yes       828.0
# 41719             SCORED              SF       Yes       886.0
# 41723             SCORED              SF        No       853.0
# 41737             SCORED              SF        No       706.0
# 41738             MISSED              SF        No       888.0
# 41740             MISSED              SF        No       889.0
# 41748             MISSED              SF        No       871.0
# 41749             MISSED              SF        No       888.0
# 41764             SCORED              SF        No       878.0
# 41765             SCORED              SF        No       878.0
# 41766             MISSED              SF        No       886.0
# 41771             MISSED              SF        No       300.0
# 41772             MISSED              SF        No       254.0
# 41779             SCORED              SF        No        52.0
# 41783             MISSED              SF        No       185.0
# 41785            BLOCKED              SF        No        52.0
# 41790             MISSED              SF        No        58.0
# 41791             SCORED              SF        No       269.0
# 41795             MISSED              SF        No        51.0
# 41798             SCORED              SF        No        58.0
# 41801             SCORED              SF        No        52.0
# 41806             SCORED              SF        No        77.0
# 41813             MISSED              SF        No       141.0
#
#       opponent_previous_shot home_team                        shot_type  \
# 35023                 SCORED       CLE                        Jump Shot
# 35028                 MISSED       CLE                        Jump Shot
# 35030                 SCORED       CLE                        Jump Shot
# 35037                 MISSED       CLE                    Running Layup
# 35044                 SCORED       CLE                     Putback Dunk
# 35054                 MISSED       CLE                             Dunk
# 35055                 MISSED       CLE                    Running Layup
# 35061                 SCORED       CLE                     Running Dunk
# 35062                BLOCKED       CLE                   Alley Oop Dunk
# 35073                 SCORED       CLE                        Jump Shot
# 35074                 MISSED       CLE               Floating Jump Shot
# 35081                 SCORED       CLE                     Driving Dunk
# 35082                 SCORED       CLE                     Running Dunk
# 35101                 MISSED       CLE             Turnaround Jump Shot
# 35121                 MISSED       TOR       Driving Floating Jump Shot
# 35122                 MISSED       TOR                    Driving Layup
# 35127                 MISSED       TOR                    Running Layup
# 35133                 SCORED       TOR       Driving Floating Jump Shot
# 35134                 SCORED       TOR                        Jump Shot
# 35143                 SCORED       TOR                            Layup
# 35144                 MISSED       TOR  Driving Floating Bank Jump Shot
# 35147                 MISSED       TOR                    Driving Layup
# 35149                 MISSED       TOR                        Jump Shot
# 35167                 SCORED       TOR                 Pullup Jump Shot
# 35169                 MISSED       TOR                 Pullup Jump Shot
# 35173                 SCORED       TOR                 Pullup Jump Shot
# 35175                 MISSED       TOR                 Pullup Jump Shot
# 35183                 SCORED       TOR                            Layup
# 35185                 MISSED       TOR                Cutting Dunk Shot
# 35194                 MISSED       TOR              Step Back Jump Shot
# ...                      ...       ...                              ...
# 41683                 MISSED       CLE                    Running Layup
# 41684                 MISSED       CLE                    Driving Layup
# 41690                 SCORED       CLE                Cutting Dunk Shot
# 41693                 SCORED       CLE                            Layup
# 41697                 SCORED       CLE                    Driving Layup
# 41705                 MISSED       CLE                    Driving Layup
# 41706                 MISSED       CLE                    Running Layup
# 41717                 SCORED       CLE             Turnaround Jump Shot
# 41719                 SCORED       CLE                    Driving Layup
# 41723                 MISSED       ATL                    Driving Layup
# 41737                BLOCKED       ATL              Step Back Jump Shot
# 41738                 MISSED       ATL                     Running Dunk
# 41740                 MISSED       ATL                   Tip Layup Shot
# 41748                 SCORED       ATL                        Jump Shot
# 41749                 MISSED       ATL                     Driving Dunk
# 41764                 SCORED       ATL                            Layup
# 41765                 SCORED       ATL                            Layup
# 41766                 SCORED       ATL                    Putback Layup
# 41771                 SCORED       ATL                 Pullup Jump Shot
# 41772                 MISSED       ATL                        Jump Shot
# 41779                 SCORED       ATL                     Driving Dunk
# 41783                 MISSED       ATL                 Pullup Jump Shot
# 41785                BLOCKED       ATL                Cutting Dunk Shot
# 41790                 MISSED       ATL                            Layup
# 41791                 MISSED       ATL                        Jump Shot
# 41795                 SCORED       ATL                    Driving Layup
# 41798                 SCORED       ATL                    Driving Layup
# 41801                 MISSED       ATL                     Driving Dunk
# 41806                 SCORED       ATL                  Fadeaway Jumper
# 41813                 MISSED       ATL               Floating Jump Shot
#
#        points away_team  location_y   time        date  shoot_player  \
# 35023       2       NYK       171.0   1:01  10/25/2016  LeBron James
# 35028       3       NYK        84.0   2:33  10/25/2016  LeBron James
# 35030       3       NYK       383.0   3:44  10/25/2016  LeBron James
# 35037       2       NYK       259.0   6:04  10/25/2016  LeBron James
# 35044       2       NYK       250.0   8:23  10/25/2016  LeBron James
# 35054       2       NYK       250.0   1:05  10/25/2016  LeBron James
# 35055       2       NYK       275.0   1:18  10/25/2016  LeBron James
# 35061       2       NYK       250.0   3:24  10/25/2016  LeBron James
# 35062       2       NYK       250.0   4:27  10/25/2016  LeBron James
# 35073       3       NYK       485.0  10:45  10/25/2016  LeBron James
# 35074       2       NYK       274.0  11:08  10/25/2016  LeBron James
# 35081       2       NYK       250.0   2:55  10/25/2016  LeBron James
# 35082       2       NYK       250.0   3:14  10/25/2016  LeBron James
# 35101       2       NYK       220.0   2:49  10/25/2016  LeBron James
# 35121       2       CLE       257.0   2:29  10/28/2016  LeBron James
# 35122       2       CLE       250.0   2:47  10/28/2016  LeBron James
# 35127       2       CLE       218.0   4:48  10/28/2016  LeBron James
# 35133       2       CLE       342.0   8:13  10/28/2016  LeBron James
# 35134       3       CLE       477.0   8:18  10/28/2016  LeBron James
# 35143       2       CLE       262.0   1:32  10/28/2016  LeBron James
# 35144       2       CLE       220.0   3:46  10/28/2016  LeBron James
# 35147       2       CLE       262.0   5:53  10/28/2016  LeBron James
# 35149       3       CLE         7.0   6:34  10/28/2016  LeBron James
# 35167       3       CLE       341.0   4:50  10/28/2016  LeBron James
# 35169       3       CLE       275.0   6:29  10/28/2016  LeBron James
# 35173       2       CLE       197.0   9:22  10/28/2016  LeBron James
# 35175       3       CLE       117.0  11:55  10/28/2016  LeBron James
# 35183       2       CLE       277.0   5:03  10/28/2016  LeBron James
# 35185       2       CLE       250.0   6:36  10/28/2016  LeBron James
# 35194       3       CLE       465.0  11:44  10/28/2016  LeBron James
# ...       ...       ...         ...    ...         ...           ...
# 41683       2       ATL       241.0   0:30    4/7/2017  LeBron James
# 41684       2       ATL       256.0   0:55    4/7/2017  LeBron James
# 41690       2       ATL       250.0   5:06    4/7/2017  LeBron James
# 41693       2       ATL       259.0   6:44    4/7/2017  LeBron James
# 41697       2       ATL       250.0   9:35    4/7/2017  LeBron James
# 41705       2       ATL       248.0   2:11    4/7/2017  LeBron James
# 41706       2       ATL       251.0   2:27    4/7/2017  LeBron James
# 41717       2       ATL       270.0   8:42    4/7/2017  LeBron James
# 41719       2       ATL       262.0   9:29    4/7/2017  LeBron James
# 41723       2       CLE       254.0   1:09    4/9/2017  LeBron James
# 41737       3       CLE       423.0   7:42    4/9/2017  LeBron James
# 41738       2       CLE       250.0   8:20    4/9/2017  LeBron James
# 41740       2       CLE       238.0   8:48    4/9/2017  LeBron James
# 41748       2       CLE        81.0   1:55    4/9/2017  LeBron James
# 41749       2       CLE       250.0   2:11    4/9/2017  LeBron James
# 41764       2       CLE       251.0   9:58    4/9/2017  LeBron James
# 41765       2       CLE       235.0  10:47    4/9/2017  LeBron James
# 41766       2       CLE       249.0  10:50    4/9/2017  LeBron James
# 41771       3       CLE       212.0   1:16    4/9/2017  LeBron James
# 41772       3       CLE        97.0   1:39    4/9/2017  LeBron James
# 41779       2       CLE       250.0   5:35    4/9/2017  LeBron James
# 41783       2       CLE       151.0   7:35    4/9/2017  LeBron James
# 41785       2       CLE       250.0   8:02    4/9/2017  LeBron James
# 41790       2       CLE       267.0  11:00    4/9/2017  LeBron James
# 41791       2       CLE       197.0  11:27    4/9/2017  LeBron James
# 41795       2       CLE       246.0   1:16    4/9/2017  LeBron James
# 41798       2       CLE       249.0   3:36    4/9/2017  LeBron James
# 41801       2       CLE       250.0   5:54    4/9/2017  LeBron James
# 41806       2       CLE       450.0   8:54    4/9/2017  LeBron James
# 41813       2       CLE       290.0   2:08    4/9/2017  LeBron James
#
#        time_from_last_shot  quarter current_shot_outcome  halfcourt_x  \
# 35023                 27.0        1               SCORED        802.0
# 35028                  6.0        1               MISSED        697.0
# 35030                 42.0        1               MISSED        669.0
# 35037                 17.0        1               SCORED        883.0
# 35044                  4.0        1               SCORED        881.0
# 35054                 25.0        2               SCORED        881.0
# 35055                 13.0        2               MISSED        866.0
# 35061                 12.0        2               SCORED        881.0
# 35062                 63.0        2               SCORED        881.0
# 35073                 89.0        2               MISSED        883.0
# 35074                 23.0        2               MISSED        782.0
# 35081                 30.0        3               SCORED        888.0
# 35082                 19.0        3               SCORED        888.0
# 35101                 22.0        4               SCORED        814.0
# 35121                 24.0        1               MISSED        833.0
# 35122                 18.0        1               MISSED        878.0
# 35127                 45.0        1               SCORED        882.0
# 35133                 28.0        1               MISSED        878.0
# 35134                  5.0        1               SCORED        895.0
# 35143                 34.0        2               SCORED        878.0
# 35144                134.0        2               SCORED        886.0
# 35147                 45.0        2               MISSED        886.0
# 35149                 19.0        2               MISSED        878.0
# 35167                 58.0        3               MISSED        630.0
# 35169                 52.0        3               MISSED        623.0
# 35173                 41.0        3               MISSED        767.0
# 35175                 86.0        3               SCORED        659.0
# 35183                 24.0        4               SCORED        893.0
# 35185                 21.0        4               SCORED        881.0
# 35194                 28.0        4               MISSED        756.0
# ...                    ...      ...                  ...          ...
# 41683                  NaN        3               SCORED        900.0
# 41684                 25.0        3               SCORED        894.0
# 41690                 35.0        3               SCORED        888.0
# 41693                 29.0        3               SCORED        878.0
# 41697                 36.0        3               SCORED        890.0
# 41705                 33.0        4               MISSED        890.0
# 41706                 16.0        4               SCORED        890.0
# 41717                 41.0        4               MISSED        828.0
# 41719                 33.0        4               SCORED        886.0
# 41723                 31.0        1              BLOCKED        853.0
# 41737                 61.0        1               MISSED        706.0
# 41738                 38.0        1               SCORED        888.0
# 41740                  3.0        1               SCORED        889.0
# 41748                 46.0        2               MISSED        871.0
# 41749                 16.0        2               SCORED        888.0
# 41764                 26.0        2               SCORED        878.0
# 41765                 49.0        2               MISSED        878.0
# 41766                  3.0        2               SCORED        886.0
# 41771                 29.0        3               MISSED        633.0
# 41772                 23.0        3               SCORED        679.0
# 41779                 35.0        3               SCORED        881.0
# 41783                 31.0        3               MISSED        748.0
# 41785                  2.0        3               SCORED        881.0
# 41790                 18.0        3               SCORED        875.0
# 41791                 27.0        3               MISSED        664.0
# 41795                 47.0        4               MISSED        882.0
# 41798                 58.0        4               SCORED        875.0
# 41801                 29.0        4               SCORED        881.0
# 41806                 31.0        4               MISSED        856.0
# 41813                 76.0        5               MISSED        792.0
#
#        halfcourt_y  left_halfcourt_x  left_halfcourt_y
# 35023        329.0             131.0             171.0
# 35028        416.0             236.0              84.0
# 35030        117.0             264.0             383.0
# 35037        241.0              50.0             259.0
# 35044        250.0              52.0             250.0
# 35054        250.0              52.0             250.0
# 35055        225.0              67.0             275.0
# 35061        250.0              52.0             250.0
# 35062        250.0              52.0             250.0
# 35073         15.0              50.0             485.0
# 35074        226.0             151.0             274.0
# 35081        250.0              45.0             250.0
# 35082        250.0              45.0             250.0
# 35101        220.0             119.0             280.0
# 35121        257.0             100.0             243.0
# 35122        250.0              55.0             250.0
# 35127        218.0              51.0             282.0
# 35133        342.0              55.0             158.0
# 35134        477.0              38.0              23.0
# 35143        262.0              55.0             238.0
# 35144        220.0              47.0             280.0
# 35147        262.0              47.0             238.0
# 35149          7.0              55.0             493.0
# 35167        159.0             303.0             341.0
# 35169        225.0             310.0             275.0
# 35173        303.0             166.0             197.0
# 35175        383.0             274.0             117.0
# 35183        223.0              40.0             277.0
# 35185        250.0              52.0             250.0
# 35194         35.0             177.0             465.0
# ...            ...               ...               ...
# 41683        241.0              33.0             259.0
# 41684        256.0              39.0             244.0
# 41690        250.0              45.0             250.0
# 41693        259.0              55.0             241.0
# 41697        250.0              43.0             250.0
# 41705        248.0              43.0             252.0
# 41706        251.0              43.0             249.0
# 41717        270.0             105.0             230.0
# 41719        262.0              47.0             238.0
# 41723        254.0              80.0             246.0
# 41737        423.0             227.0              77.0
# 41738        250.0              45.0             250.0
# 41740        238.0              44.0             262.0
# 41748         81.0              62.0             419.0
# 41749        250.0              45.0             250.0
# 41764        251.0              55.0             249.0
# 41765        235.0              55.0             265.0
# 41766        249.0              47.0             251.0
# 41771        288.0             300.0             212.0
# 41772        403.0             254.0              97.0
# 41779        250.0              52.0             250.0
# 41783        349.0             185.0             151.0
# 41785        250.0              52.0             250.0
# 41790        233.0              58.0             267.0
# 41791        303.0             269.0             197.0
# 41795        254.0              51.0             246.0
# 41798        251.0              58.0             249.0
# 41801        250.0              52.0             250.0
# 41806         50.0              77.0             450.0
# 41813        210.0             141.0             290.0
#
# [1344 rows x 20 columns]

# %%
# LeBron plot
# Note how the shots can be color coded using an np.where statement. 

hxL = LeBron['halfcourt_x']
hyL = LeBron['halfcourt_y']
colors = np.where(LeBron['current_shot_outcome']=='SCORED','r',np.where(LeBron['current_shot_outcome']=='MISSED','b','g'))
plt.figure(figsize=(94/12,50/6))
plt.scatter(hxL,hyL, s=10, c= colors, marker= '.')
plt.grid(True)
plt.title("LeBron James", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'LeBron James')

# %%
# Steph Curry plot

Curry = shot[shot['shoot_player']=='Stephen Curry']
hxC = Curry['halfcourt_x']
hyC = Curry['halfcourt_y']
colors = np.where(Curry['current_shot_outcome']=='SCORED','r',np.where(Curry['current_shot_outcome']=='MISSED','b','g'))
plt.figure(figsize=(94/12,50/6))
plt.scatter(hxC,hyC, s=10, c= colors, marker= '.')
plt.grid(True)
plt.title("Steph Curry", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Steph Curry')

# %%
# LeBron James and Steph Curry side by side

f = plt.figure(figsize=(94/6,50/6))
ax = f.add_subplot(121)
colors = np.where(LeBron['current_shot_outcome']=='SCORED','r',np.where(LeBron['current_shot_outcome']=='MISSED','b','g'))
ax = plt.scatter(hxL,hyL, s=10, c= colors, marker= '.')
plt.grid(True)
plt.title("LeBron James", fontsize = 15)
ax = f.add_subplot(122)
colors = np.where(Curry['current_shot_outcome']=='SCORED','r',np.where(Curry['current_shot_outcome']=='MISSED','b','g'))
ax = plt.scatter(hxC,hyC, s=10, c= colors, marker= '.')
plt.grid(True)
plt.title("Steph Curry", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Steph Curry')

# %% [markdown]
# These simple plots make clear some of the differences between the two players. It is clearly visible that Curry shoots more from the three-point line than LeBron, while LeBron is more active on the paint. Some more subtle differences are also visible. LeBron is more active on the left hand side of the court, while Curry is equally active on both sides. Curry also shoots more thre-pointers from the corners.

# %% [markdown]
# ## Self Test
#
# Identify two other players in the data and generate a similar comparison for those players.

# %%
#Let's compare 2 future Hall of Fame point guards, Kyrie Irving and Russell Westbrook

# Russell Westbrook's stats
Westbrook = shot[shot['shoot_player']=='Russell Westbrook']
Westbrook
# Out:
#        self_previous_shot player_position home_game  location_x  \
# 140311                NaN              PG        No       853.0
# 140314             MISSED              PG        No       802.0
# 140319            BLOCKED              PG        No       853.0
# 140321             SCORED              PG        No       809.0
# 140322             MISSED              PG        No       895.0
# 140324             MISSED              PG        No       882.0
# 140326             SCORED              PG        No       886.0
# 140349             MISSED              PG        No       819.0
# 140353             SCORED              PG        No       889.0
# 140354             SCORED              PG        No       763.0
# 140357             MISSED              PG        No       881.0
# 140362             MISSED              PG        No       177.0
# 140366             MISSED              PG        No        64.0
# 140374             SCORED              PG        No        52.0
# 140375             SCORED              PG        No       126.0
# 140392            BLOCKED              PG        No       313.0
# 140393             MISSED              PG        No       107.0
# 140396             SCORED              PG        No       308.0
# 140399             SCORED              PG        No        97.0
# 140401             MISSED              PG        No        53.0
# 140402             MISSED              PG        No        53.0
# 140405                NaN              PG       Yes        50.0
# 140409             MISSED              PG       Yes       116.0
# 140412             SCORED              PG       Yes        46.0
# 140413             MISSED              PG       Yes       249.0
# 140414             MISSED              PG       Yes       126.0
# 140416             SCORED              PG       Yes        92.0
# 140418             MISSED              PG       Yes        53.0
# 140430            BLOCKED              PG       Yes        54.0
# 140431             SCORED              PG       Yes       121.0
# ...                   ...             ...       ...         ...
# 147234             MISSED              PG        No       711.0
# 147236             MISSED              PG        No       887.0
# 147244             MISSED              PG        No       200.0
# 147247             MISSED              PG        No       241.0
# 147249             SCORED              PG        No       241.0
# 147252             MISSED              PG        No       259.0
# 147254             SCORED              PG        No        98.0
# 147255             MISSED              PG        No       298.0
# 147258             MISSED              PG        No        62.0
# 147259             SCORED              PG        No        59.0
# 147276             MISSED              PG        No        52.0
# 147278             MISSED              PG        No       318.0
# 147279             SCORED              PG        No       225.0
# 147281             SCORED              PG        No        69.0
# 147283             MISSED              PG        No       313.0
# 147284             MISSED              PG        No        62.0
# 147285             SCORED              PG        No       187.0
# 147286             MISSED              PG        No       220.0
# 147287             MISSED              PG        No        67.0
# 147288             SCORED              PG        No       338.0
# 147376             MISSED              PG       Yes       166.0
# 147379            BLOCKED              PG       Yes       112.0
# 147383             MISSED              PG       Yes       190.0
# 147391             SCORED              PG       Yes        83.0
# 147392            BLOCKED              PG       Yes       298.0
# 147393             MISSED              PG       Yes       118.0
# 147394             SCORED              PG       Yes       241.0
# 147420            BLOCKED              PG       Yes       126.0
# 147425             MISSED              PG       Yes       298.0
# 147429             SCORED              PG       Yes       320.0
#
#        opponent_previous_shot home_team                  shot_type  points  \
# 140311                    NaN       PHI                  Jump Shot       2
# 140314                 SCORED       PHI           Pullup Jump Shot       2
# 140319                 SCORED       PHI                  Jump Shot       2
# 140321                 SCORED       PHI           Pullup Jump Shot       2
# 140322                 SCORED       PHI  Driving Finger Roll Layup       2
# 140324                BLOCKED       PHI              Running Layup       2
# 140326                 MISSED       PHI       Turnaround Jump Shot       2
# 140349                 SCORED       PHI        Step Back Jump Shot       2
# 140353                 SCORED       PHI                  Jump Shot       2
# 140354                 MISSED       PHI        Step Back Jump Shot       2
# 140357                 SCORED       PHI                      Layup       2
# 140362                 SCORED       PHI  Running Pull-Up Jump Shot       2
# 140366                 MISSED       PHI                  Jump Shot       2
# 140374                BLOCKED       PHI               Running Dunk       2
# 140375                BLOCKED       PHI        Step Back Jump Shot       2
# 140392                 SCORED       PHI                  Jump Shot       3
# 140393                 SCORED       PHI                  Jump Shot       2
# 140396                 MISSED       PHI           Pullup Jump Shot       3
# 140399                 SCORED       PHI                  Jump Shot       2
# 140401                 MISSED       PHI              Driving Layup       2
# 140402                 MISSED       PHI        Step Back Jump Shot       2
# 140405                 SCORED       OKL                      Layup       2
# 140409                 SCORED       OKL           Pullup Jump Shot       2
# 140412                 SCORED       OKL              Driving Layup       2
# 140413                 SCORED       OKL                  Jump Shot       3
# 140414                 MISSED       OKL           Pullup Jump Shot       2
# 140416                 SCORED       OKL           Pullup Jump Shot       2
# 140418                 SCORED       OKL              Driving Layup       2
# 140430                 MISSED       OKL                      Layup       2
# 140431                 SCORED       OKL                  Jump Shot       2
# ...                       ...       ...                        ...     ...
# 147234                 SCORED       DEN                  Jump Shot       3
# 147236                 SCORED       DEN             Tip Layup Shot       2
# 147244                 MISSED       DEN                  Jump Shot       2
# 147247                 SCORED       DEN                  Jump Shot       2
# 147249                 SCORED       DEN        Step Back Jump Shot       3
# 147252                 SCORED       DEN           Pullup Jump Shot       3
# 147254                 MISSED       DEN             Jump Bank Shot       2
# 147255                 SCORED       DEN                  Jump Shot       3
# 147258                 SCORED       DEN              Driving Layup       2
# 147259                 MISSED       DEN                  Jump Shot       3
# 147276                 SCORED       DEN               Driving Dunk       2
# 147278                 MISSED       DEN           Pullup Jump Shot       3
# 147279                 MISSED       DEN                  Jump Shot       3
# 147281                 SCORED       DEN  Driving Finger Roll Layup       2
# 147283                 SCORED       DEN                  Jump Shot       3
# 147284                 MISSED       DEN      Running Reverse Layup       2
# 147285                 MISSED       DEN                  Jump Shot       3
# 147286                 MISSED       DEN                  Jump Shot       3
# 147287                 MISSED       DEN              Driving Layup       2
# 147288                 MISSED       DEN                  Jump Shot       3
# 147376                 MISSED       OKL           Pullup Jump Shot       2
# 147379                 SCORED       OKL       Turnaround Jump Shot       2
# 147383                 SCORED       OKL           Pullup Jump Shot       2
# 147391                 MISSED       OKL              Running Layup       2
# 147392                 MISSED       OKL           Pullup Jump Shot       3
# 147393                 SCORED       OKL           Pullup Jump Shot       3
# 147394                 MISSED       OKL                  Jump Shot       3
# 147420                 MISSED       OKL       Turnaround Jump Shot       2
# 147425                 SCORED       OKL                  Jump Shot       3
# 147429                 MISSED       OKL           Pullup Jump Shot       3
#
#        away_team  location_y   time        date       shoot_player  \
# 140311       OKL        76.0   0:17  10/26/2016  Russell Westbrook
# 140314       OKL       367.0   1:51  10/26/2016  Russell Westbrook
# 140319       OKL       308.0   3:59  10/26/2016  Russell Westbrook
# 140321       OKL       433.0   4:54  10/26/2016  Russell Westbrook
# 140322       OKL       270.0   5:44  10/26/2016  Russell Westbrook
# 140324       OKL       241.0   7:08  10/26/2016  Russell Westbrook
# 140326       OKL       401.0   7:59  10/26/2016  Russell Westbrook
# 140349       OKL       138.0   7:26  10/26/2016  Russell Westbrook
# 140353       OKL       434.0   9:38  10/26/2016  Russell Westbrook
# 140354       OKL       136.0  10:07  10/26/2016  Russell Westbrook
# 140357       OKL       235.0  11:38  10/26/2016  Russell Westbrook
# 140362       OKL       248.0   1:35  10/26/2016  Russell Westbrook
# 140366       OKL       413.0   3:54  10/26/2016  Russell Westbrook
# 140374       OKL       250.0   8:18  10/26/2016  Russell Westbrook
# 140375       OKL       401.0   8:58  10/26/2016  Russell Westbrook
# 140392       OKL       264.0   5:59  10/26/2016  Russell Westbrook
# 140393       OKL       352.0   6:10  10/26/2016  Russell Westbrook
# 140396       OKL       231.0   7:51  10/26/2016  Russell Westbrook
# 140399       OKL       406.0   9:16  10/26/2016  Russell Westbrook
# 140401       OKL       238.0  10:24  10/26/2016  Russell Westbrook
# 140402       OKL       424.0  10:53  10/26/2016  Russell Westbrook
# 140405       PHX       260.0   0:47  10/28/2016  Russell Westbrook
# 140409       PHX       349.0   3:09  10/28/2016  Russell Westbrook
# 140412       PHX       241.0   5:15  10/28/2016  Russell Westbrook
# 140413       PHX       108.0   5:40  10/28/2016  Russell Westbrook
# 140414       PHX       148.0   6:11  10/28/2016  Russell Westbrook
# 140416       PHX       321.0   7:26  10/28/2016  Russell Westbrook
# 140418       PHX       249.0   8:07  10/28/2016  Russell Westbrook
# 140430       PHX       259.0   3:48  10/28/2016  Russell Westbrook
# 140431       PHX       102.0   4:33  10/28/2016  Russell Westbrook
# ...          ...         ...    ...         ...                ...
# 147234       OKL        68.0  10:14    4/9/2017  Russell Westbrook
# 147236       OKL       280.0  10:47    4/9/2017  Russell Westbrook
# 147244       OKL       251.0   3:06    4/9/2017  Russell Westbrook
# 147247       OKL       243.0   3:44    4/9/2017  Russell Westbrook
# 147249       OKL        99.0   4:35    4/9/2017  Russell Westbrook
# 147252       OKL       408.0   5:44    4/9/2017  Russell Westbrook
# 147254       OKL       113.0   6:44    4/9/2017  Russell Westbrook
# 147255       OKL        64.0   7:25    4/9/2017  Russell Westbrook
# 147258       OKL       218.0   8:24    4/9/2017  Russell Westbrook
# 147259       OKL        10.0   8:50    4/9/2017  Russell Westbrook
# 147276       OKL       250.0   5:40    4/9/2017  Russell Westbrook
# 147278       OKL       220.0   6:43    4/9/2017  Russell Westbrook
# 147279       OKL       436.0   7:11    4/9/2017  Russell Westbrook
# 147281       OKL       265.0   8:25    4/9/2017  Russell Westbrook
# 147283       OKL       192.0   9:02    4/9/2017  Russell Westbrook
# 147284       OKL       262.0   9:33    4/9/2017  Russell Westbrook
# 147285       OKL       452.0  10:09    4/9/2017  Russell Westbrook
# 147286       OKL        53.0  10:27    4/9/2017  Russell Westbrook
# 147287       OKL       225.0  11:33    4/9/2017  Russell Westbrook
# 147288       OKL        38.0  12:00    4/9/2017  Russell Westbrook
# 147376       DEN       369.0   0:44   4/12/2017  Russell Westbrook
# 147379       DEN       292.0   1:43   4/12/2017  Russell Westbrook
# 147383       DEN       305.0   3:54   4/12/2017  Russell Westbrook
# 147391       DEN       247.0   6:53   4/12/2017  Russell Westbrook
# 147392       DEN       197.0   7:18   4/12/2017  Russell Westbrook
# 147393       DEN        25.0   7:55   4/12/2017  Russell Westbrook
# 147394       DEN        69.0   8:28   4/12/2017  Russell Westbrook
# 147420       DEN       367.0   8:51   4/12/2017  Russell Westbrook
# 147425       DEN       370.0  11:09   4/12/2017  Russell Westbrook
# 147429       DEN       120.0  12:00   4/12/2017  Russell Westbrook
#
#         time_from_last_shot  quarter current_shot_outcome  halfcourt_x  \
# 140311                  NaN        1               MISSED        853.0
# 140314                 50.0        1               SCORED        802.0
# 140319                 27.0        1              BLOCKED        853.0
# 140321                 34.0        1               MISSED        809.0
# 140322                 50.0        1               SCORED        895.0
# 140324                 45.0        1               SCORED        882.0
# 140326                 28.0        1               SCORED        886.0
# 140349                 23.0        2               SCORED        819.0
# 140353                 48.0        2               SCORED        889.0
# 140354                 29.0        2               MISSED        763.0
# 140357                  8.0        2               MISSED        881.0
# 140362                 27.0        3               MISSED        756.0
# 140366                 32.0        3               SCORED        869.0
# 140374                 14.0        3               SCORED        881.0
# 140375                 40.0        3               MISSED        807.0
# 140392                 39.0        4               MISSED        620.0
# 140393                 11.0        4               MISSED        826.0
# 140396                 52.0        4               SCORED        625.0
# 140399                 26.0        4               SCORED        836.0
# 140401                 37.0        4               MISSED        880.0
# 140402                 29.0        4               SCORED        880.0
# 140405                  NaN        1               MISSED        883.0
# 140409                 16.0        1               MISSED        817.0
# 140412                 25.0        1               MISSED        887.0
# 140413                 25.0        1               MISSED        684.0
# 140414                 31.0        1               SCORED        807.0
# 140416                 36.0        1               MISSED        841.0
# 140418                 19.0        1               SCORED        880.0
# 140430                  2.0        2               SCORED        879.0
# 140431                 45.0        2               MISSED        812.0
# ...                     ...      ...                  ...          ...
# 147234                 34.0        2               SCORED        711.0
# 147236                  3.0        2               SCORED        887.0
# 147244                 33.0        3               MISSED        733.0
# 147247                 11.0        3               MISSED        692.0
# 147249                 27.0        3               SCORED        692.0
# 147252                 28.0        3               MISSED        674.0
# 147254                 28.0        3               MISSED        835.0
# 147255                 41.0        3               MISSED        635.0
# 147258                 18.0        3               SCORED        871.0
# 147259                 26.0        3               SCORED        874.0
# 147276                 29.0        4               MISSED        881.0
# 147278                 22.0        4               SCORED        615.0
# 147279                 28.0        4               MISSED        708.0
# 147281                 42.0        4               SCORED        864.0
# 147283                  9.0        4               MISSED        620.0
# 147284                 31.0        4               SCORED        871.0
# 147285                 36.0        4               MISSED        746.0
# 147286                 18.0        4               MISSED        713.0
# 147287                 66.0        4               SCORED        866.0
# 147288                 27.0        4               SCORED        595.0
# 147376                 21.0        1               MISSED        767.0
# 147379                 20.0        1               MISSED        821.0
# 147383                 26.0        1               MISSED        743.0
# 147391                 18.0        1              BLOCKED        850.0
# 147392                 25.0        1               MISSED        635.0
# 147393                 37.0        1               SCORED        815.0
# 147394                 33.0        1               MISSED        692.0
# 147420                 47.0        2               SCORED        807.0
# 147425                 35.0        2               MISSED        635.0
# 147429                 49.0        2               MISSED        613.0
#
#         halfcourt_y  left_halfcourt_x  left_halfcourt_y
# 140311         76.0              80.0             424.0
# 140314        367.0             131.0             133.0
# 140319        308.0              80.0             192.0
# 140321        433.0             124.0              67.0
# 140322        270.0              38.0             230.0
# 140324        241.0              51.0             259.0
# 140326        401.0              47.0              99.0
# 140349        138.0             114.0             362.0
# 140353        434.0              44.0              66.0
# 140354        136.0             170.0             364.0
# 140357        235.0              52.0             265.0
# 140362        252.0             177.0             248.0
# 140366         87.0              64.0             413.0
# 140374        250.0              52.0             250.0
# 140375         99.0             126.0             401.0
# 140392        236.0             313.0             264.0
# 140393        148.0             107.0             352.0
# 140396        269.0             308.0             231.0
# 140399         94.0              97.0             406.0
# 140401        262.0              53.0             238.0
# 140402         76.0              53.0             424.0
# 140405        240.0              50.0             260.0
# 140409        151.0             116.0             349.0
# 140412        259.0              46.0             241.0
# 140413        392.0             249.0             108.0
# 140414        352.0             126.0             148.0
# 140416        179.0              92.0             321.0
# 140418        251.0              53.0             249.0
# 140430        241.0              54.0             259.0
# 140431        398.0             121.0             102.0
# ...             ...               ...               ...
# 147234         68.0             222.0             432.0
# 147236        280.0              46.0             220.0
# 147244        249.0             200.0             251.0
# 147247        257.0             241.0             243.0
# 147249        401.0             241.0              99.0
# 147252         92.0             259.0             408.0
# 147254        387.0              98.0             113.0
# 147255        436.0             298.0              64.0
# 147258        282.0              62.0             218.0
# 147259        490.0              59.0              10.0
# 147276        250.0              52.0             250.0
# 147278        280.0             318.0             220.0
# 147279         64.0             225.0             436.0
# 147281        235.0              69.0             265.0
# 147283        308.0             313.0             192.0
# 147284        238.0              62.0             262.0
# 147285         48.0             187.0             452.0
# 147286        447.0             220.0              53.0
# 147287        275.0              67.0             225.0
# 147288        462.0             338.0              38.0
# 147376        131.0             166.0             369.0
# 147379        208.0             112.0             292.0
# 147383        195.0             190.0             305.0
# 147391        253.0              83.0             247.0
# 147392        303.0             298.0             197.0
# 147393        475.0             118.0              25.0
# 147394        431.0             241.0              69.0
# 147420        133.0             126.0             367.0
# 147425        130.0             298.0             370.0
# 147429        380.0             320.0             120.0
#
# [1940 rows x 20 columns]

# %%
# Westbrook plot
# Note how the shots can be color coded using an np.where statement. 

hx_Westbrook = Westbrook['halfcourt_x']
hy_Westbrook = Westbrook['halfcourt_y']
colors = np.where(Westbrook['current_shot_outcome']=='SCORED','r',np.where(Westbrook['current_shot_outcome']=='MISSED','b','g'))
plt.figure(figsize=(94/12,50/6))
plt.scatter(hx_Westbrook,hy_Westbrook, s=10, c= colors, marker= '.')
plt.grid(True)
plt.title("Russell Westbrook", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Russell Westbrook')

# %%
# Kyrie Irving plot

Kyrie_Irving = shot[shot['shoot_player']=='Kyrie Irving']
hx_Kyrie_Irving = Kyrie_Irving['halfcourt_x']
hy_Kyrie_Irving = Kyrie_Irving['halfcourt_y']
colors = np.where(Kyrie_Irving['current_shot_outcome']=='SCORED','r',np.where(Kyrie_Irving['current_shot_outcome']=='MISSED','b','g'))
plt.figure(figsize=(94/12,50/6))
plt.scatter(hx_Kyrie_Irving,hy_Kyrie_Irving, s=10, c= colors, marker= '.')
plt.grid(True)
plt.title("Kyrie Irving", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Kyrie Irving')

# %%
#  Kyrie Irving and Russell Westbrook side by side

f = plt.figure(figsize=(94/6,50/6))
ax = f.add_subplot(121)
colors = np.where(Westbrook['current_shot_outcome']=='SCORED','r',np.where(Westbrook['current_shot_outcome']=='MISSED','b','g'))
ax = plt.scatter(hx_Westbrook,hy_Westbrook, s=10, c= colors, marker= '.')
plt.grid(True)
plt.title("Russell Westbrook", fontsize = 15)
ax = f.add_subplot(122)
colors = np.where(Kyrie_Irving['current_shot_outcome']=='SCORED','r',np.where(Kyrie_Irving['current_shot_outcome']=='MISSED','b','g'))
ax = plt.scatter(hx_Kyrie_Irving,hy_Kyrie_Irving, s=10, c= colors, marker= '.')
plt.grid(True)
plt.title("Kyrie Irving", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Kyrie Irving')

# %% [raw]
# As a final exercise we zoom in on the data to see what it looks like close up. We can identify a particular location based on our grid. First, we look at shots from the paint. We can define the paint here as x coordinates between 700 and 900, and y coordinates 200 and 300. We first create this subset, then we create the plot.

# %%
# Define the subset

rect1 = shot[(((shot['location_x']>700) & (shot['location_x']<900)) & \
                 ((shot['location_y'] > 200) & (shot['location_y'] < 300)))]
rect1
# Out:
#        self_previous_shot player_position home_game  location_x  \
# 49                 MISSED              PG       Yes       886.0
# 51                 MISSED              PF       Yes       871.0
# 53                 MISSED              PF       Yes       868.0
# 54                 SCORED              PG       Yes       882.0
# 59                 MISSED               C       Yes       888.0
# 60                 SCORED               C       Yes       804.0
# 63                 SCORED              SG       Yes       878.0
# 66                 SCORED              SF       Yes       878.0
# 67                 SCORED              PF       Yes       887.0
# 70                 SCORED              SG       Yes       878.0
# 71                 MISSED              SG       Yes       881.0
# 78                 SCORED              SG       Yes       784.0
# 81                 MISSED              PF       Yes       882.0
# 82                 SCORED              SF       Yes       866.0
# 83                 SCORED               C       Yes       882.0
# 84                 SCORED               F       Yes       889.0
# 88                    NaN              PG        No       848.0
# 89                 MISSED               C        No       890.0
# 90                 MISSED               C        No       894.0
# 91                 MISSED              PF        No       868.0
# 94                 MISSED              PG        No       858.0
# 102                SCORED              PF        No       890.0
# 106                SCORED              PF        No       888.0
# 109                SCORED              SG        No       873.0
# 111                MISSED              SG        No       888.0
# 113                MISSED               C        No       888.0
# 114                SCORED              SG        No       725.0
# 115                MISSED              SG        No       895.0
# 116                SCORED               G        No       725.0
# 119                MISSED              SF        No       838.0
# ...                   ...             ...       ...         ...
# 209920             SCORED              SG        No       888.0
# 209923             SCORED               C        No       878.0
# 209925             SCORED               C        No       878.0
# 209927             SCORED              SG        No       887.0
# 209929             SCORED              SF        No       804.0
# 209932             MISSED              SF        No       881.0
# 209934             MISSED              SF        No       882.0
# 209935             MISSED               C        No       882.0
# 209936             SCORED              SF        No       880.0
# 209937             SCORED               G        No       878.0
# 209938             SCORED               C        No       853.0
# 209940             MISSED              PG        No       868.0
# 209942             SCORED               C        No       882.0
# 209986             SCORED              SF        No       882.0
# 209988             MISSED              SF        No       881.0
# 209994             MISSED               G        No       878.0
# 209995            BLOCKED              SF        No       878.0
# 209996            BLOCKED              SF        No       861.0
# 209997             SCORED              SF        No       888.0
# 209998             MISSED               C        No       878.0
# 209999             SCORED              PG        No       873.0
# 210000             MISSED               G        No       876.0
# 210002             SCORED              PG        No       890.0
# 210010             MISSED               C        No       873.0
# 210012             MISSED               C        No       822.0
# 210017             SCORED               G        No       882.0
# 210018             SCORED              PG        No       824.0
# 210020             MISSED               G        No       886.0
# 210021             MISSED              PG        No       706.0
# 210027             MISSED              SF        No       878.0
#
#        opponent_previous_shot home_team                     shot_type  points  \
# 49                     SCORED       ATL                 Driving Layup       2
# 51                     SCORED       ATL                 Driving Layup       2
# 53                     SCORED       ATL                 Driving Layup       2
# 54                     MISSED       ATL                 Driving Layup       2
# 59                     MISSED       ATL                          Dunk       2
# 60                     MISSED       ATL            Floating Jump Shot       2
# 63                     MISSED       ATL          Jr. 2' Running Layup       2
# 66                     MISSED       ATL                 Running Layup       2
# 67                     MISSED       ATL                 Driving Layup       2
# 70                     SCORED       ATL          Jr. 1' Driving Layup       2
# 71                     SCORED       ATL          Jr. 1' Putback Layup       2
# 78                     MISSED       ATL    Jr. 11' Floating Jump Shot       2
# 81                     MISSED       ATL               Alley Oop Layup       2
# 82                     MISSED       ATL     Driving Finger Roll Layup       2
# 83                     MISSED       ATL                 Reverse Layup       2
# 84                     SCORED       ATL            Cutting Layup Shot       2
# 88                     SCORED       PHI                     Jump Shot       2
# 89                     SCORED       PHI                         Layup       2
# 90                     SCORED       PHI                         Layup       2
# 91                     MISSED       PHI                     Jump Shot       2
# 94                     MISSED       PHI    Driving Floating Jump Shot       2
# 102                    MISSED       PHI                 Reverse Layup       2
# 106                    SCORED       PHI                  Running Dunk       2
# 109                    SCORED       PHI     Jr. 3' Cutting Layup Shot       2
# 111                    SCORED       PHI             Jr.  Running Dunk       2
# 113                    SCORED       PHI                  Running Dunk       2
# 114                    SCORED       PHI             Jr. 17' Jump Shot       2
# 115                    MISSED       PHI  Jr. 1' Driving Reverse Layup       2
# 116                    MISSED       PHI                     Jump Shot       2
# 119                    MISSED       PHI                     Jump Shot       2
# ...                       ...       ...                           ...     ...
# 209920                 SCORED       DET                          Dunk       2
# 209923                 MISSED       DET                         Layup       2
# 209925                 MISSED       DET                 Driving Layup       2
# 209927                 MISSED       DET                         Layup       2
# 209929                 MISSED       DET                     Jump Shot       2
# 209932                 MISSED       DET                         Layup       2
# 209934                 SCORED       DET                         Layup       2
# 209935                 MISSED       DET                         Layup       2
# 209936                 MISSED       DET                 Driving Layup       2
# 209937                 MISSED       DET                         Layup       2
# 209938                 SCORED       DET                     Jump Shot       2
# 209940                 MISSED       DET                     Jump Shot       2
# 209942                 SCORED       DET                         Layup       2
# 209986                    NaN       MIA          Jr. 1' Driving Layup       2
# 209988                 MISSED       MIA          Jr. 2' Driving Layup       2
# 209994                 SCORED       MIA                     Jump Shot       2
# 209995                 SCORED       MIA                  Jr. 1' Layup       2
# 209996                 MISSED       MIA      Jr. 3' Running Jump Shot       2
# 209997                 MISSED       MIA                     Jr.  Dunk       2
# 209998                 SCORED       MIA                         Layup       2
# 209999                 MISSED       MIA             Finger Roll Layup       2
# 210000                 MISSED       MIA                 Running Layup       2
# 210002                 MISSED       MIA             Finger Roll Layup       2
# 210010                 SCORED       MIA            Cutting Layup Shot       2
# 210012                 SCORED       MIA                     Jump Shot       2
# 210017                 MISSED       MIA                 Driving Layup       2
# 210018                 SCORED       MIA                     Jump Shot       2
# 210020                 SCORED       MIA                 Driving Layup       2
# 210021                 SCORED       MIA           Step Back Jump Shot       2
# 210027                 SCORED       MIA     Jr. 3' Cutting Layup Shot       2
#
#        away_team  location_y   time        date       shoot_player  \
# 49           WAS       257.0   0:15  10/27/2016    Dennis Schroder
# 51           WAS       246.0   1:26  10/27/2016       Paul Millsap
# 53           WAS       257.0   3:31  10/27/2016       Paul Millsap
# 54           WAS       228.0   4:11  10/27/2016    Dennis Schroder
# 59           WAS       250.0   6:51  10/27/2016      Dwight Howard
# 60           WAS       235.0   7:25  10/27/2016       Mike Muscala
# 63           WAS       230.0   9:28  10/27/2016   Tim Hardaway Jr.
# 66           WAS       231.0  10:51  10/27/2016    Thabo Sefolosha
# 67           WAS       235.0   0:31  10/27/2016       Paul Millsap
# 70           WAS       248.0   1:43  10/27/2016   Tim Hardaway Jr.
# 71           WAS       241.0   1:44  10/27/2016   Tim Hardaway Jr.
# 78           WAS       233.0   5:37  10/27/2016   Tim Hardaway Jr.
# 81           WAS       261.0   7:13  10/27/2016       Paul Millsap
# 82           WAS       230.0   7:46  10/27/2016    Thabo Sefolosha
# 83           WAS       241.0   9:01  10/27/2016       Mike Muscala
# 84           WAS       226.0  10:17  10/27/2016    DeAndre' Bembry
# 88           ATL       264.0   1:04  10/29/2016    Dennis Schroder
# 89           ATL       274.0   1:08  10/29/2016      Dwight Howard
# 90           ATL       230.0   1:10  10/29/2016      Dwight Howard
# 91           ATL       212.0   1:32  10/29/2016       Paul Millsap
# 94           ATL       259.0   2:49  10/29/2016    Dennis Schroder
# 102          ATL       264.0   5:52  10/29/2016       Paul Millsap
# 106          ATL       250.0   8:35  10/29/2016     Kris Humphries
# 109          ATL       272.0  10:08  10/29/2016   Tim Hardaway Jr.
# 111          ATL       250.0  11:05  10/29/2016   Tim Hardaway Jr.
# 113          ATL       250.0  11:32  10/29/2016       Mike Muscala
# 114          ATL       215.0   0:16  10/29/2016   Tim Hardaway Jr.
# 115          ATL       250.0   0:35  10/29/2016   Tim Hardaway Jr.
# 116          ATL       262.0   1:07  10/29/2016    Malcolm Delaney
# 119          ATL       264.0   3:37  10/29/2016      Kent Bazemore
# ...          ...         ...    ...         ...                ...
# 209920       WAS       250.0   7:37   4/10/2017       Bradley Beal
# 209923       WAS       250.0   8:40   4/10/2017        Ian Mahinmi
# 209925       WAS       250.0   9:49   4/10/2017        Ian Mahinmi
# 209927       WAS       249.0  11:35   4/10/2017       Bradley Beal
# 209929       WAS       270.0   0:40   4/10/2017   Bojan Bogdanovic
# 209932       WAS       251.0   3:00   4/10/2017   Bojan Bogdanovic
# 209934       WAS       252.0   4:23   4/10/2017   Bojan Bogdanovic
# 209935       WAS       254.0   4:35   4/10/2017        Jason Smith
# 209936       WAS       251.0   5:02   4/10/2017   Bojan Bogdanovic
# 209937       WAS       240.0   5:52   4/10/2017   Tomas Satoransky
# 209938       WAS       217.0   6:44   4/10/2017      Marcin Gortat
# 209940       WAS       295.0   7:59   4/10/2017   Brandon Jennings
# 209942       WAS       252.0   9:30   4/10/2017      Marcin Gortat
# 209986       WAS       252.0   0:40   4/12/2017    Kelly Oubre Jr.
# 209988       WAS       235.0   1:47   4/12/2017    Kelly Oubre Jr.
# 209994       WAS       215.0   4:41   4/12/2017   Tomas Satoransky
# 209995       WAS       246.0   4:44   4/12/2017    Kelly Oubre Jr.
# 209996       WAS       270.0   4:59   4/12/2017    Otto Porter Jr.
# 209997       WAS       250.0   5:22   4/12/2017    Kelly Oubre Jr.
# 209998       WAS       231.0   5:49   4/12/2017      Marcin Gortat
# 209999       WAS       248.0   6:22   4/12/2017   Brandon Jennings
# 210000       WAS       249.0   6:40   4/12/2017   Tomas Satoransky
# 210002       WAS       270.0   7:03   4/12/2017   Brandon Jennings
# 210010       WAS       261.0  11:20   4/12/2017        Jason Smith
# 210012       WAS       285.0   0:36   4/12/2017        Jason Smith
# 210017       WAS       241.0   4:19   4/12/2017  Sheldon McClellan
# 210018       WAS       251.0   4:50   4/12/2017         Trey Burke
# 210020       WAS       238.0   6:18   4/12/2017  Sheldon McClellan
# 210021       WAS       236.0   7:17   4/12/2017         Trey Burke
# 210027       WAS       226.0  10:00   4/12/2017    Otto Porter Jr.
#
#         time_from_last_shot  quarter current_shot_outcome  halfcourt_x  \
# 49                      NaN        3               SCORED        886.0
# 51                     24.0        3               SCORED        871.0
# 53                     58.0        3               SCORED        868.0
# 54                     40.0        3               SCORED        882.0
# 59                     22.0        3               SCORED        888.0
# 60                     34.0        3               MISSED        804.0
# 63                     59.0        3               SCORED        878.0
# 66                     20.0        3               SCORED        878.0
# 67                      NaN        4               MISSED        887.0
# 70                     23.0        4               MISSED        878.0
# 71                      1.0        4               SCORED        881.0
# 78                     51.0        4               SCORED        784.0
# 81                     16.0        4               SCORED        882.0
# 82                     33.0        4               SCORED        866.0
# 83                     75.0        4               SCORED        882.0
# 84                     76.0        4               SCORED        889.0
# 88                      NaN        1               MISSED        848.0
# 89                      4.0        1               MISSED        890.0
# 90                      2.0        1               MISSED        894.0
# 91                     22.0        1               MISSED        868.0
# 94                     26.0        1               SCORED        858.0
# 102                    19.0        1               SCORED        890.0
# 106                    22.0        1               SCORED        888.0
# 109                    44.0        1              BLOCKED        873.0
# 111                    31.0        1               SCORED        888.0
# 113                    23.0        1               SCORED        888.0
# 114                     NaN        2               MISSED        725.0
# 115                    19.0        2               SCORED        895.0
# 116                    32.0        2               MISSED        725.0
# 119                    41.0        2              BLOCKED        838.0
# ...                     ...      ...                  ...          ...
# 209920                 26.0        1               SCORED        888.0
# 209923                 21.0        1               MISSED        878.0
# 209925                 31.0        1               SCORED        878.0
# 209927                 84.0        1               SCORED        887.0
# 209929                  NaN        2               SCORED        804.0
# 209932                 23.0        2               MISSED        881.0
# 209934                 24.0        2               MISSED        882.0
# 209935                 12.0        2               SCORED        882.0
# 209936                 27.0        2               SCORED        880.0
# 209937                 50.0        2               SCORED        878.0
# 209938                 52.0        2               MISSED        853.0
# 209940                 51.0        2              BLOCKED        868.0
# 209942                 25.0        2               SCORED        882.0
# 209986                 24.0        1               SCORED        882.0
# 209988                 30.0        1              BLOCKED        881.0
# 209994                 44.0        1              BLOCKED        878.0
# 209995                  3.0        1              BLOCKED        878.0
# 209996                 15.0        1               SCORED        861.0
# 209997                 23.0        1               MISSED        888.0
# 209998                 27.0        1               SCORED        878.0
# 209999                 33.0        1               MISSED        873.0
# 210000                 18.0        1              BLOCKED        876.0
# 210002                 15.0        1               SCORED        890.0
# 210010                 27.0        1               SCORED        873.0
# 210012                  NaN        2               MISSED        822.0
# 210017                 81.0        2               SCORED        882.0
# 210018                 31.0        2               SCORED        824.0
# 210020                 34.0        2               MISSED        886.0
# 210021                 59.0        2               SCORED        706.0
# 210027                 27.0        2               SCORED        878.0
#
#         halfcourt_y  left_halfcourt_x  left_halfcourt_y
# 49            257.0              47.0             243.0
# 51            246.0              62.0             254.0
# 53            257.0              65.0             243.0
# 54            228.0              51.0             272.0
# 59            250.0              45.0             250.0
# 60            235.0             129.0             265.0
# 63            230.0              55.0             270.0
# 66            231.0              55.0             269.0
# 67            235.0              46.0             265.0
# 70            248.0              55.0             252.0
# 71            241.0              52.0             259.0
# 78            233.0             149.0             267.0
# 81            261.0              51.0             239.0
# 82            230.0              67.0             270.0
# 83            241.0              51.0             259.0
# 84            226.0              44.0             274.0
# 88            264.0              85.0             236.0
# 89            274.0              43.0             226.0
# 90            230.0              39.0             270.0
# 91            212.0              65.0             288.0
# 94            259.0              75.0             241.0
# 102           264.0              43.0             236.0
# 106           250.0              45.0             250.0
# 109           272.0              60.0             228.0
# 111           250.0              45.0             250.0
# 113           250.0              45.0             250.0
# 114           215.0             208.0             285.0
# 115           250.0              38.0             250.0
# 116           262.0             208.0             238.0
# 119           264.0              95.0             236.0
# ...             ...               ...               ...
# 209920        250.0              45.0             250.0
# 209923        250.0              55.0             250.0
# 209925        250.0              55.0             250.0
# 209927        249.0              46.0             251.0
# 209929        270.0             129.0             230.0
# 209932        251.0              52.0             249.0
# 209934        252.0              51.0             248.0
# 209935        254.0              51.0             246.0
# 209936        251.0              53.0             249.0
# 209937        240.0              55.0             260.0
# 209938        217.0              80.0             283.0
# 209940        295.0              65.0             205.0
# 209942        252.0              51.0             248.0
# 209986        252.0              51.0             248.0
# 209988        235.0              52.0             265.0
# 209994        215.0              55.0             285.0
# 209995        246.0              55.0             254.0
# 209996        270.0              72.0             230.0
# 209997        250.0              45.0             250.0
# 209998        231.0              55.0             269.0
# 209999        248.0              60.0             252.0
# 210000        249.0              57.0             251.0
# 210002        270.0              43.0             230.0
# 210010        261.0              60.0             239.0
# 210012        285.0             111.0             215.0
# 210017        241.0              51.0             259.0
# 210018        251.0             109.0             249.0
# 210020        238.0              47.0             262.0
# 210021        236.0             227.0             264.0
# 210027        226.0              55.0             274.0
#
# [45163 rows x 20 columns]

# %%
# Shots on the paint

xr = rect1['location_x']
yr = rect1['location_y']
colors = np.where(rect1['current_shot_outcome']=='SCORED','r',np.where(rect1['current_shot_outcome']=='MISSED','b','g'))
plt.figure(figsize=(94/6,50/6))
plt.scatter(xr,yr, s=50, c= colors, marker= '.')
plt.grid(True)

# %% [markdown]
# Note how the locations appear in vertical lines. This reflects the fact that the resolution of the location coding is finite. The difference between adjacent vertical lines on this plot is approximately one inch (2.5cm).
#
# But we can still zoom in further. Below we look at the area immediately under the basket:

# %%
# subset area

rect2 = shot[(((shot['location_x']>850) & (shot['location_x']<875)) & \
                 ((shot['location_y'] > 240) & (shot['location_y'] < 260)))]
rect2
# Out:
#        self_previous_shot player_position home_game  location_x  \
# 51                 MISSED              PF       Yes       871.0
# 53                 MISSED              PF       Yes       868.0
# 94                 MISSED              PG        No       858.0
# 120               BLOCKED               C        No       866.0
# 299                SCORED               C       Yes       873.0
# 379                MISSED              PG        No       873.0
# 637                MISSED               C       Yes       866.0
# 657                MISSED              PG       Yes       873.0
# 770                SCORED               C        No       873.0
# 775                SCORED               C        No       871.0
# 787                MISSED              SF        No       868.0
# 928                MISSED               C        No       873.0
# 1010               MISSED              PG        No       868.0
# 1013               MISSED               C        No       868.0
# 1169               SCORED              PF       Yes       868.0
# 1177               SCORED              SF        No       868.0
# 1182               SCORED               C        No       858.0
# 1210               MISSED               C        No       874.0
# 1256               MISSED               C        No       853.0
# 1270               MISSED               C        No       866.0
# 1289               MISSED              SF        No       863.0
# 1341               SCORED               C        No       868.0
# 1430               MISSED              SF        No       873.0
# 1461               SCORED              PG        No       863.0
# 1536               SCORED               C        No       858.0
# 1672               MISSED              SG       Yes       873.0
# 1724               MISSED               C        No       873.0
# 1728               SCORED              PG        No       853.0
# 1730               MISSED               C        No       863.0
# 1733               MISSED              SG        No       871.0
# ...                   ...             ...       ...         ...
# 208833             SCORED              PG       Yes       858.0
# 209164             MISSED               C       Yes       873.0
# 209240             MISSED              SG        No       868.0
# 209304             SCORED              PG        No       873.0
# 209312             SCORED              PF        No       873.0
# 209315             SCORED               C        No       853.0
# 209318             MISSED              SF        No       868.0
# 209332             SCORED               C        No       871.0
# 209339             MISSED              SG        No       873.0
# 209340             MISSED              PF        No       872.0
# 209345             SCORED              PG        No       871.0
# 209404             SCORED              PG        No       858.0
# 209405             MISSED               C        No       873.0
# 209406             SCORED              PG        No       861.0
# 209409             SCORED              PG        No       866.0
# 209410            BLOCKED               C        No       868.0
# 209415             MISSED               C        No       858.0
# 209512             MISSED              SF        No       873.0
# 209518             MISSED               C        No       853.0
# 209524             MISSED              PG        No       873.0
# 209571                NaN              SG        No       871.0
# 209578             SCORED              SG        No       861.0
# 209580             SCORED               C        No       871.0
# 209597             MISSED              SF        No       861.0
# 209605             SCORED              PG        No       871.0
# 209719             MISSED              PF       Yes       868.0
# 209749             MISSED               C        No       851.0
# 209863             MISSED               C       Yes       873.0
# 209887             SCORED              SF       Yes       868.0
# 209999             SCORED              PG        No       873.0
#
#        opponent_previous_shot home_team                        shot_type  \
# 51                     SCORED       ATL                    Driving Layup
# 53                     SCORED       ATL                    Driving Layup
# 94                     MISSED       PHI       Driving Floating Jump Shot
# 120                    MISSED       PHI                            Layup
# 299                    MISSED       ATL                    Driving Layup
# 379                    SCORED       WAS        Running Finger Roll Layup
# 637                    MISSED       ATL                            Layup
# 657                    SCORED       ATL                    Driving Layup
# 770                    MISSED       MIA                            Layup
# 775                    SCORED       MIA                  Alley Oop Layup
# 787                    MISSED       MIA            Running Reverse Layup
# 928                    SCORED       CHA                            Layup
# 1010                   SCORED       NYK                    Driving Layup
# 1013                   SCORED       NYK                            Layup
# 1169                   MISSED       ATL                    Driving Layup
# 1177                   SCORED       IND        Driving Finger Roll Layup
# 1182                   SCORED       IND                    Driving Layup
# 1210                   SCORED       IND                            Layup
# 1256                      NaN       UTA                        Hook Shot
# 1270                   MISSED       UTA                    Driving Layup
# 1289                   MISSED       UTA                    Running Layup
# 1341                   MISSED       LAL                            Layup
# 1430                   SCORED       GSW                    Running Layup
# 1461                   MISSED       GSW                    Driving Layup
# 1536                   MISSED       PHX                        Jump Shot
# 1672                  BLOCKED       ATL             Jr. 2' Driving Layup
# 1724                   MISSED       TOR                    Putback Layup
# 1728                   SCORED       TOR       Driving Floating Jump Shot
# 1730                   MISSED       TOR                   Tip Layup Shot
# 1733                   SCORED       TOR                24' 3PT Jump Shot
# ...                       ...       ...                              ...
# 208833                 SCORED       WAS                        Jump Shot
# 209164                 SCORED       WAS                            Layup
# 209240                 MISSED       CLE                    Driving Layup
# 209304                 MISSED       LAL                            Layup
# 209312                 SCORED       LAL     Morris 2' Cutting Layup Shot
# 209315                 SCORED       LAL                        Jump Shot
# 209318                 SCORED       LAL                     Jr. 2' Layup
# 209332                 SCORED       LAL                            Layup
# 209339                 SCORED       LAL                   Jump Bank Shot
# 209340                 SCORED       LAL        Morris 2' Alley Oop Layup
# 209345                 MISSED       LAL                    Reverse Layup
# 209404                 MISSED       LAC                        Jump Shot
# 209405                 MISSED       LAC                    Putback Layup
# 209406                 MISSED       LAC                    Running Layup
# 209409                 SCORED       LAC                            Layup
# 209410                 SCORED       LAC                            Layup
# 209415                 SCORED       LAC                        Hook Shot
# 209512                BLOCKED       UTA                            Layup
# 209518                 SCORED       UTA                        Hook Shot
# 209524                 MISSED       UTA                    Driving Layup
# 209571                    NaN       GSW                    Driving Layup
# 209578                 SCORED       GSW                    Driving Layup
# 209580                 MISSED       GSW               Cutting Layup Shot
# 209597                 SCORED       GSW                     Jr. 3' Layup
# 209605                 MISSED       GSW                            Layup
# 209719                 SCORED       WAS  Morris 2' Driving Reverse Layup
# 209749                 SCORED       NYK                        Jump Shot
# 209863                 SCORED       WAS                   Tip Layup Shot
# 209887                 SCORED       WAS                            Layup
# 209999                 MISSED       MIA                Finger Roll Layup
#
#         points away_team  location_y   time        date      shoot_player  \
# 51           2       WAS       246.0   1:26  10/27/2016      Paul Millsap
# 53           2       WAS       257.0   3:31  10/27/2016      Paul Millsap
# 94           2       ATL       259.0   2:49  10/29/2016   Dennis Schroder
# 120          2       ATL       254.0   4:14  10/29/2016     Dwight Howard
# 299          2       LAL       248.0   2:43   11/2/2016     Dwight Howard
# 379          2       ATL       251.0  10:15   11/4/2016   Dennis Schroder
# 637          2       CHI       248.0   5:59   11/9/2016     Dwight Howard
# 657          2       CHI       250.0   5:05   11/9/2016   Dennis Schroder
# 770          2       ATL       257.0   5:15  11/15/2016     Dwight Howard
# 775          2       ATL       244.0   8:07  11/15/2016      Mike Muscala
# 787          2       ATL       249.0   2:20  11/15/2016     Kent Bazemore
# 928          2       ATL       241.0   5:38  11/18/2016     Dwight Howard
# 1010         2       ATL       252.0   5:34  11/20/2016   Dennis Schroder
# 1013         2       ATL       249.0   7:09  11/20/2016      Mike Muscala
# 1169         2       NOP       249.0  11:28  11/22/2016    Kris Humphries
# 1177         2       ATL       259.0   3:28  11/23/2016     Kent Bazemore
# 1182         2       ATL       259.0   6:39  11/23/2016     Dwight Howard
# 1210         2       ATL       245.0   7:57  11/23/2016     Dwight Howard
# 1256         2       ATL       241.0   0:36  11/25/2016     Dwight Howard
# 1270         2       ATL       241.0   8:06  11/25/2016     Dwight Howard
# 1289         2       ATL       250.0   7:37  11/25/2016     Kent Bazemore
# 1341         2       ATL       252.0   1:56  11/27/2016     Dwight Howard
# 1430         2       ATL       251.0   2:37  11/28/2016     Kent Bazemore
# 1461         2       ATL       241.0   8:43  11/28/2016   Dennis Schroder
# 1536         2       ATL       252.0   1:45  11/30/2016      Mike Muscala
# 1672         2       DET       248.0   2:22   12/2/2016  Tim Hardaway Jr.
# 1724         2       ATL       248.0   5:38   12/3/2016      Mike Muscala
# 1728         2       ATL       248.0   8:26   12/3/2016   Dennis Schroder
# 1730         2       ATL       246.0   9:11   12/3/2016     Dwight Howard
# 1733         3       ATL       246.0  11:23   12/3/2016  Tim Hardaway Jr.
# ...        ...       ...         ...    ...         ...               ...
# 208833       2       CHI       251.0  11:10   3/17/2017         John Wall
# 209164       2       BRO       251.0   0:13   3/24/2017     Marcin Gortat
# 209240       2       WAS       256.0   2:06   3/25/2017      Bradley Beal
# 209304       2       WAS       258.0   3:44   3/28/2017         John Wall
# 209312       2       WAS       257.0   6:56   3/28/2017   Markieff Morris
# 209315       2       WAS       258.0   8:29   3/28/2017     Marcin Gortat
# 209318       2       WAS       257.0  10:19   3/28/2017   Kelly Oubre Jr.
# 209332       2       WAS       257.0   5:01   3/28/2017       Ian Mahinmi
# 209339       2       WAS       250.0   8:16   3/28/2017      Bradley Beal
# 209340       2       WAS       251.0   8:34   3/28/2017   Markieff Morris
# 209345       2       WAS       255.0  11:57   3/28/2017         John Wall
# 209404       2       WAS       248.0   6:28   3/29/2017         John Wall
# 209405       2       WAS       246.0   6:33   3/29/2017     Marcin Gortat
# 209406       2       WAS       244.0   6:50   3/29/2017         John Wall
# 209409       2       WAS       256.0   8:22   3/29/2017         John Wall
# 209410       2       WAS       244.0   8:33   3/29/2017       Jason Smith
# 209415       2       WAS       252.0  11:17   3/29/2017       Ian Mahinmi
# 209512       2       WAS       251.0   2:17   3/31/2017  Bojan Bogdanovic
# 209518       2       WAS       249.0   5:44   3/31/2017       Ian Mahinmi
# 209524       2       WAS       254.0   8:26   3/31/2017         John Wall
# 209571       2       WAS       256.0   0:23    4/2/2017      Bradley Beal
# 209578       2       WAS       241.0   3:47    4/2/2017      Bradley Beal
# 209580       2       WAS       252.0   4:43    4/2/2017     Marcin Gortat
# 209597       2       WAS       249.0   0:37    4/2/2017   Kelly Oubre Jr.
# 209605       2       WAS       249.0   8:05    4/2/2017         John Wall
# 209719       2       CHA       248.0   6:27    4/4/2017   Markieff Morris
# 209749       2       WAS       254.0   1:50    4/6/2017     Marcin Gortat
# 209863       2       MIA       259.0   1:46    4/8/2017     Marcin Gortat
# 209887       2       MIA       251.0   4:02    4/8/2017  Bojan Bogdanovic
# 209999       2       WAS       248.0   6:22   4/12/2017  Brandon Jennings
#
#         time_from_last_shot  quarter current_shot_outcome  halfcourt_x  \
# 51                     24.0        3               SCORED        871.0
# 53                     58.0        3               SCORED        868.0
# 94                     26.0        1               SCORED        858.0
# 120                    37.0        2              BLOCKED        866.0
# 299                    30.0        3               SCORED        873.0
# 379                    41.0        2               SCORED        873.0
# 637                    30.0        3               MISSED        866.0
# 657                    41.0        4               MISSED        873.0
# 770                    39.0        1               MISSED        873.0
# 775                    87.0        1               MISSED        871.0
# 787                    14.0        2               SCORED        868.0
# 928                    19.0        1               SCORED        873.0
# 1010                   26.0        1              BLOCKED        868.0
# 1013                   48.0        1               MISSED        868.0
# 1169                   95.0        4               SCORED        868.0
# 1177                   29.0        1               SCORED        868.0
# 1182                   74.0        1               SCORED        858.0
# 1210                    2.0        2              BLOCKED        874.0
# 1256                   13.0        1              BLOCKED        853.0
# 1270                   29.0        1              BLOCKED        866.0
# 1289                   22.0        2               MISSED        863.0
# 1341                   33.0        1               SCORED        868.0
# 1430                   33.0        1               MISSED        873.0
# 1461                   27.0        2              BLOCKED        863.0
# 1536                   40.0        2               MISSED        858.0
# 1672                    6.0        4               SCORED        873.0
# 1724                    4.0        2               SCORED        873.0
# 1728                   30.0        2               SCORED        853.0
# 1730                    2.0        2               MISSED        863.0
# 1733                   31.0        2               MISSED        871.0
# ...                     ...      ...                  ...          ...
# 208833                 42.0        3              BLOCKED        858.0
# 209164                  NaN        3               MISSED        873.0
# 209240                 21.0        2              BLOCKED        868.0
# 209304                 11.0        1              BLOCKED        873.0
# 209312                 30.0        1               SCORED        873.0
# 209315                 42.0        1              BLOCKED        853.0
# 209318                  3.0        1              BLOCKED        868.0
# 209332                 28.0        2               SCORED        871.0
# 209339                  9.0        2               MISSED        873.0
# 209340                 18.0        2               SCORED        872.0
# 209345                 33.0        2               MISSED        871.0
# 209404                 27.0        1               MISSED        858.0
# 209405                  5.0        1               SCORED        873.0
# 209406                 17.0        1               SCORED        861.0
# 209409                 29.0        1              BLOCKED        866.0
# 209410                 11.0        1               MISSED        868.0
# 209415                  2.0        1               MISSED        858.0
# 209512                 26.0        2              BLOCKED        873.0
# 209518                 64.0        2               MISSED        853.0
# 209524                 48.0        2               SCORED        873.0
# 209571                  NaN        1               MISSED        871.0
# 209578                 40.0        1               SCORED        861.0
# 209580                 37.0        1               SCORED        871.0
# 209597                  2.0        2              BLOCKED        861.0
# 209605                 23.0        2              BLOCKED        871.0
# 209719                 32.0        3               SCORED        868.0
# 209749                 58.0        1               SCORED        851.0
# 209863                  3.0        3               SCORED        873.0
# 209887                 62.0        4              BLOCKED        868.0
# 209999                 33.0        1               MISSED        873.0
#
#         halfcourt_y  left_halfcourt_x  left_halfcourt_y
# 51            246.0              62.0             254.0
# 53            257.0              65.0             243.0
# 94            259.0              75.0             241.0
# 120           254.0              67.0             246.0
# 299           248.0              60.0             252.0
# 379           251.0              60.0             249.0
# 637           248.0              67.0             252.0
# 657           250.0              60.0             250.0
# 770           257.0              60.0             243.0
# 775           244.0              62.0             256.0
# 787           249.0              65.0             251.0
# 928           241.0              60.0             259.0
# 1010          252.0              65.0             248.0
# 1013          249.0              65.0             251.0
# 1169          249.0              65.0             251.0
# 1177          259.0              65.0             241.0
# 1182          259.0              75.0             241.0
# 1210          245.0              59.0             255.0
# 1256          241.0              80.0             259.0
# 1270          241.0              67.0             259.0
# 1289          250.0              70.0             250.0
# 1341          252.0              65.0             248.0
# 1430          251.0              60.0             249.0
# 1461          241.0              70.0             259.0
# 1536          252.0              75.0             248.0
# 1672          248.0              60.0             252.0
# 1724          248.0              60.0             252.0
# 1728          248.0              80.0             252.0
# 1730          246.0              70.0             254.0
# 1733          246.0              62.0             254.0
# ...             ...               ...               ...
# 208833        251.0              75.0             249.0
# 209164        251.0              60.0             249.0
# 209240        256.0              65.0             244.0
# 209304        258.0              60.0             242.0
# 209312        257.0              60.0             243.0
# 209315        258.0              80.0             242.0
# 209318        257.0              65.0             243.0
# 209332        257.0              62.0             243.0
# 209339        250.0              60.0             250.0
# 209340        251.0              61.0             249.0
# 209345        255.0              62.0             245.0
# 209404        248.0              75.0             252.0
# 209405        246.0              60.0             254.0
# 209406        244.0              72.0             256.0
# 209409        256.0              67.0             244.0
# 209410        244.0              65.0             256.0
# 209415        252.0              75.0             248.0
# 209512        251.0              60.0             249.0
# 209518        249.0              80.0             251.0
# 209524        254.0              60.0             246.0
# 209571        256.0              62.0             244.0
# 209578        241.0              72.0             259.0
# 209580        252.0              62.0             248.0
# 209597        249.0              72.0             251.0
# 209605        249.0              62.0             251.0
# 209719        248.0              65.0             252.0
# 209749        254.0              82.0             246.0
# 209863        259.0              60.0             241.0
# 209887        251.0              65.0             249.0
# 209999        248.0              60.0             252.0
#
# [3533 rows x 20 columns]

# %%
# Shots under the basket

xq = rect2['location_x']
yq = rect2['location_y']
colors = np.where(rect2['current_shot_outcome']=='SCORED','r',np.where(rect2['current_shot_outcome']=='MISSED','b','g'))
plt.figure(figsize=(94/6,50/6))
plt.scatter(xq,yq, s=50, c= colors, marker= '.')
plt.grid(True)

# %% [markdown]
# It turns out that this degree of resolution is not very informative. The problem is that the all the points are piled upon each other and there is nothing in between - recalling that the gaps are still approximately one inch. It would only be possble to extract a reliable picture if the data were even more fine grained.

# %% [markdown]
# # Conclusion
#
# Using charts can be incredibly helpful in understanding the pattern of events on the field/court/pitch/ice. Charts can suggest to us logical relationships which may exist, but they do not quantify them. In the next two weeks we turn to regression analysis, which is one of the most common ways to quantify relationships among variables.
